# %%
import pandas as pd

# %%
data_2020=pd.read_excel("2020 order data.xlsx")             #firstdataframe
data_2021=pd.read_excel("2021 order data.xlsx")

# %%
data_2020
# Out:
#     Order ID  Customer ID.1                     Restaurant  Cookies Shipped  \
# 0     413383           2385                 YT Restaurants              936
# 1     751142           3261  Quick Bite Convenience Stores              987
# 2     876056           2740  Quick Bite Convenience Stores              270
# 3     548247           2910  Quick Bite Convenience Stores              925
# 4     626350           4585                 YT Restaurants              974
# ..       ...            ...                            ...              ...
# 80    558199           2703  Quick Bite Convenience Stores              381
# 81    681993           1751                 YT Restaurants              589
# 82    214016           2186                 Park & Eat LLC              679
# 83    773259           2249                 Park & Eat LLC              396
# 84    994115           4032                 YT Restaurants              370
#
# ...

# %%
#combine the 2 dataframe

# %%
combined_sales=pd.concat([data_2020,data_2021],ignore_index=True)

#ignore_index will ignore thr

# %%
combined_sales
# Out:
#      Order ID  Customer ID.1                     Restaurant  Cookies Shipped  \
# 0      413383           2385                 YT Restaurants              936
# 1      751142           3261  Quick Bite Convenience Stores              987
# 2      876056           2740  Quick Bite Convenience Stores              270
# 3      548247           2910  Quick Bite Convenience Stores              925
# 4      626350           4585                 YT Restaurants              974
# ..        ...            ...                            ...              ...
# 165    558199           3931  Quick Bite Convenience Stores              259
# 166    681993           2868                 YT Restaurants              389
# 167    214016           4599                 Park & Eat LLC              314
# 168    773259           4308                 Park & Eat LLC              642
# 169    994115           2160                 YT Restaurants              590
#
# ...

# %%
#see all rows in the datase

# %%
pd.set_option("display.max_rows",None)

# %%
combined_sales
# Out:
#      Order ID  Customer ID.1                     Restaurant  Cookies Shipped  \
# 0      413383           2385                 YT Restaurants              936
# 1      751142           3261  Quick Bite Convenience Stores              987
# 2      876056           2740  Quick Bite Convenience Stores              270
# 3      548247           2910  Quick Bite Convenience Stores              925
# 4      626350           4585                 YT Restaurants              974
# 5      200181           3679                Cascade Grovers              454
# 6      711368           3282                 YT Restaurants              484
# 7      958419           2256                Cascade Grovers              269
# 8      808349           3853  Quick Bite Convenience Stores              396
# 9      392582           1668  Quick Bite Convenience Stores              121
# 10     415147           4015                 YT Restaurants              373
# ...

# %%
#axis=1 means horizontal concentration

# %%
combined_sales2=pd.concat([data_2020,data_2021], axis=1)

# %%
combined_sales2
# Out:
#     Order ID  Customer ID.1                     Restaurant  Cookies Shipped  \
# 0     413383           2385                 YT Restaurants              936
# 1     751142           3261  Quick Bite Convenience Stores              987
# 2     876056           2740  Quick Bite Convenience Stores              270
# 3     548247           2910  Quick Bite Convenience Stores              925
# 4     626350           4585                 YT Restaurants              974
# 5     200181           3679                Cascade Grovers              454
# 6     711368           3282                 YT Restaurants              484
# 7     958419           2256                Cascade Grovers              269
# 8     808349           3853  Quick Bite Convenience Stores              396
# 9     392582           1668  Quick Bite Convenience Stores              121
# 10    415147           4015                 YT Restaurants              373
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
combined_sales2
# Out:
#     Order ID  Customer ID.1                     Restaurant  Cookies Shipped  \
# 0     413383           2385                 YT Restaurants              936
# 1     751142           3261  Quick Bite Convenience Stores              987
# 2     876056           2740  Quick Bite Convenience Stores              270
# 3     548247           2910  Quick Bite Convenience Stores              925
# 4     626350           4585                 YT Restaurants              974
# 5     200181           3679                Cascade Grovers              454
# 6     711368           3282                 YT Restaurants              484
# 7     958419           2256                Cascade Grovers              269
# 8     808349           3853  Quick Bite Convenience Stores              396
# 9     392582           1668  Quick Bite Convenience Stores              121
# 10    415147           4015                 YT Restaurants              373
# ...

# %%
pd.set_option("display.max_colwidth",None)
#increase the width of a colum

# %%
combined_sales.groupby("Restaurant").sum("numeric_only")["profit"]
# Out:
# Restaurant
# Acme Grocery Stores               182939.0
# Cascade Grovers                  1032406.5
# Park & Eat LLC                    353123.5
# Quick Bite Convenience Stores     877906.0
# YT Restaurants                    867349.0
# Name: profit, dtype: float64

# %%
#between function is used to extract date or values between a range

# %%
combined_sales["Order Date"].between("2020-11-10" , "2020-11-30")

#locate rows
combined_sales.loc[combined_sales["Order Date"]].between("2020-11-10" , "2020-11-30")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...
